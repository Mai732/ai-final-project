# %%
! pip install requests beautifulsoup4 sentence-transformers faiss-cpu google-generativeai
# Out:
# Requirement already satisfied: requests in c:\users\nt\anaconda3\lib\site-packages (2.34.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\nt\anaconda3\lib\site-packages (4.13.5)
# Requirement already satisfied: sentence-transformers in c:\users\nt\anaconda3\lib\site-packages (5.6.0)
# Requirement already satisfied: faiss-cpu in c:\users\nt\anaconda3\lib\site-packages (1.14.3)
# Requirement already satisfied: google-generativeai in c:\users\nt\anaconda3\lib\site-packages (0.8.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\nt\anaconda3\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nt\anaconda3\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\nt\anaconda3\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\nt\anaconda3\lib\site-packages (from requests) (2025.11.12)
# Requirement already satisfied: soupsieve>1.2 in c:\users\nt\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\nt\anaconda3\lib\site-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\nt\anaconda3\lib\site-packages (from sentence-transformers) (5.12.1)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\users\nt\anaconda3\lib\site-packages (from sentence-transformers) (1.19.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\nt\anaconda3\lib\site-packages (from sentence-transformers) (2.12.1)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\nt\anaconda3\lib\site-packages (from sentence-transformers) (2.3.5)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\nt\anaconda3\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\nt\anaconda3\lib\site-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: tqdm>=4.0.0 in c:\users\nt\anaconda3\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\nt\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\nt\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\nt\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\nt\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer in c:\users\nt\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\nt\anaconda3\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.8.0)
# Requirement already satisfied: click>=8.4.0 in c:\users\nt\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\nt\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\nt\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\users\nt\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\nt\anaconda3\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: anyio in c:\users\nt\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\nt\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\nt\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\nt\anaconda3\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\users\nt\anaconda3\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (14.2.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\nt\anaconda3\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\nt\anaconda3\lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\nt\anaconda3\lib\site-packages (from google-generativeai) (2.31.0)
# Requirement already satisfied: google-api-python-client in c:\users\nt\anaconda3\lib\site-packages (from google-generativeai) (2.198.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\nt\anaconda3\lib\site-packages (from google-generativeai) (2.55.1)
# Requirement already satisfied: protobuf in c:\users\nt\anaconda3\lib\site-packages (from google-generativeai) (5.29.6)
# Requirement already satisfied: pydantic in c:\users\nt\anaconda3\lib\site-packages (from google-generativeai) (2.13.4)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\nt\anaconda3\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.28.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in c:\users\nt\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (1.75.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.41.0 in c:\users\nt\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.80.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.41.0 in c:\users\nt\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\nt\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\nt\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (46.0.3)
# Requirement already satisfied: colorama in c:\users\nt\anaconda3\lib\site-packages (from click>=8.4.0->huggingface-hub>=0.23.0->sentence-transformers) (0.4.6)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\nt\anaconda3\lib\site-packages (from cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\nt\anaconda3\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\nt\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\nt\anaconda3\lib\site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\nt\anaconda3\lib\site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\nt\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\nt\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\nt\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.5.0)
# Requirement already satisfied: setuptools<82 in c:\users\nt\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\nt\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\nt\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in c:\users\nt\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\nt\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\nt\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\nt\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.32.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\nt\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.4.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\nt\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: pyparsing<4,>=3.1 in c:\users\nt\anaconda3\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nt\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\nt\anaconda3\lib\site-packages (from pydantic->google-generativeai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\nt\anaconda3\lib\site-packages (from pydantic->google-generativeai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\nt\anaconda3\lib\site-packages (from pydantic->google-generativeai) (0.4.2)

# %%
import requests
from bs4 import BeautifulSoup
import json
import time
import random
import re
import os
import faiss
import numpy as np
import google.generativeai as genai
from sentence_transformers import SentenceTransformer

# %%
# Scrape Allrecipes Dataset:


HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36"
}

CATEGORY_URLS = [
    ("Breakfast",  "https://www.allrecipes.com/recipes/78/breakfast-and-brunch/"),
    ("Dinner",     "https://www.allrecipes.com/recipes/17562/dinner/"),
    ("Desserts",   "https://www.allrecipes.com/recipes/79/desserts/"),
    ("Salads",     "https://www.allrecipes.com/recipes/96/salad/"),
    ("Soups",      "https://www.allrecipes.com/recipes/94/soups-stews-and-chili/"),
]

MAX_RECIPES_PER_CATEGORY = 30   


def get_recipe_links(category_url, max_links=10):
    """Collect recipe page URLs from a category listing page."""
    links = []
    try:
        resp = requests.get(category_url, headers=HEADERS, timeout=10)
        soup = BeautifulSoup(resp.text, "html.parser")

        # Allrecipes recipe cards carry href like /recipe/NNNNNN/...
        for a in soup.find_all("a", href=True):
            href = a["href"]
            if re.match(r"https://www\.allrecipes\.com/recipe/\d+/", href):
                if href not in links:
                    links.append(href)
            if len(links) >= max_links:
                break
    except Exception as e:
        print(f"  [link error] {e}")
    return links


def scrape_recipe(url, category, record_id):
    """Scrape a single recipe page and return a structured dict."""
    try:
        resp = requests.get(url, headers=HEADERS, timeout=10)
        soup = BeautifulSoup(resp.text, "html.parser")

        # ── Title ──────────────────────────────────────────────────────────
        title_tag = soup.find("h1")
        title = title_tag.get_text(strip=True) if title_tag else ""

        # ── Description ───────────────────────────────────────────────────
        desc_tag = soup.find("p", {"class": lambda c: c and "recipe__summary" in " ".join(c)})
        if not desc_tag:
            desc_tag = soup.find("div", {"class": lambda c: c and "recipe__summary" in " ".join(c) if c else False})
        description = desc_tag.get_text(strip=True) if desc_tag else ""

        # ── Ingredients ───────────────────────────────────────────────────
        ingredient_tags = soup.find_all("li", {"class": lambda c: c and "ingredient" in " ".join(c) if c else False})
        if not ingredient_tags:
            ingredient_tags = soup.select("ul.mm-recipes-structured-ingredients__list li")
        ingredients = [i.get_text(" ", strip=True) for i in ingredient_tags if i.get_text(strip=True)]

        # ── Instructions ──────────────────────────────────────────────────
        step_tags = soup.find_all("li", {"class": lambda c: c and "step" in " ".join(c) if c else False})
        if not step_tags:
            step_tags = soup.select("ol.comp.mntl-sc-block-group--OL li")
        instructions = [s.get_text(" ", strip=True) for s in step_tags if s.get_text(strip=True)]

        # Skip if core content missing
        if not title or not ingredients or not instructions:
            return None

        return {
            "record_id": record_id,
            "title": title,
            "source_url": url,
            "category": category,
            "description": description,
            "ingredients": ingredients,
            "instructions": instructions,
        }

    except Exception as e:
        print(f"  [scrape error] {url} → {e}")
        return None


# ── Main scraping loop ──────────────────────────────────────────────────────
all_recipes = []
record_id = 1

for category, cat_url in CATEGORY_URLS:
    print(f"\n Category: {category}")
    links = get_recipe_links(cat_url, MAX_RECIPES_PER_CATEGORY)
    print(f"  Found {len(links)} links")

    for url in links:
        recipe = scrape_recipe(url, category, record_id)
        if recipe:
            all_recipes.append(recipe)
            print(f" [{record_id}] {recipe['title']}")
            record_id += 1
        # Responsible scraping: random delay 2–4 s
        time.sleep(random.uniform(2, 4))

# Save raw data
with open("recipes_raw.json", "w", encoding="utf-8") as f:
    json.dump(all_recipes, f, indent=2, ensure_ascii=False)

print(f"\n Scraped {len(all_recipes)} recipes → recipes_raw.json")
# Out:
#  Category: Breakfast
#   Found 8 links
#  [1] Oatmeal Breakfast Cookies
#  [2] Sheet Pan Brunch Totchos
#  [3] Bacon Tater Egg Cups
#  [4] Easy Sausage Gravy and Biscuits
#  [5] Bauernomlett (Farmer's Omelet)
#  [6] Apple Fritter Pancakes
#  [7] Leftover Roast Beef Hash
#  [8] Pumpkin Waffles
#
#  Category: Dinner
#   Found 1 links
#  [9] Thai Red Curry Soup
#
#  Category: Desserts
#   Found 2 links
#  [10] Watermelon-Mint Paletas
#  [11] Orange Party Cake
#
#  Category: Salads
#   Found 30 links
#  [12] Spinach and Strawberry Salad
#  [13] Chef John's Green Goddess Dressing
#  [14] Shrimp Pasta Salad
#  [15] Sweet and Creamy Cranberry Salad
#  [16] Barley, Shrimp, and Corn Salad
#  [17] Potato Salad
#  [18] Easy Coleslaw Dressing
#  [19] Watermelon Salad
#  [20] Greek Pasta Salad with Roasted Vegetables and Feta
#  [21] Garden Pasta Salad
#  [22] No-Mayonnaise Ranch Dressing
#  [23] Winter Fruit Salad with Poppyseed Dressing
#  [24] Lemon Poppyseed Dressing
#  [25] Egg Salad with Olives
#  [26] Magical Egg Salad
#  [27] Easy Egg Salad
#  [28] Awesome Egg Salad with a Kick
#  [29] Polish Egg Salad
#  [30] Deviled Egg Salad
#  [31] My Favorite No-Mayo Egg Salad
#  [32] Avocado Egg Salad
#  [33] The Cheesecake Factory Santa Fe Salad
#  [34] Classic Macaroni Salad
#  [35] Cucumber Salad
#  [36] Our Favorite Balsamic Vinaigrette
#  [37] Homemade Ranch Dressing
#  [38] Simple Italian Salad Dressing
#  [39] Italian Dressing Mix
#  [40] Hearts of Palm and Avocado Salad
#  [41] Jen's Heavenly Egg Salad
#
#  Category: Soups
#   Found 0 links
#
#  Scraped 41 recipes → recipes_raw.json

# %%
#  Clean Dataset


with open("recipes_raw.json", "r", encoding="utf-8") as f:
    raw = json.load(f)

print(f"Raw count : {len(raw)}")


def clean_text(text: str) -> str:
    """Strip extra whitespace and non-printable chars."""
    text = re.sub(r"[\x00-\x1f\x7f]", " ", text)   # remove control chars
    text = re.sub(r"\s+", " ", text)                  # collapse spaces
    return text.strip()


def clean_recipe(r: dict) -> dict | None:
    """Return a cleaned recipe or None if it should be dropped."""
    title        = clean_text(r.get("title", ""))
    description  = clean_text(r.get("description", ""))
    ingredients  = [clean_text(i) for i in r.get("ingredients", []) if clean_text(i)]
    instructions = [clean_text(s) for s in r.get("instructions", []) if clean_text(s)]

    # Drop if essential fields are empty
    if not title or not ingredients or not instructions:
        return None

    return {
        "record_id"   : r["record_id"],
        "title"       : title,
        "source_url"  : r["source_url"],
        "category"    : r.get("category", ""),
        "description" : description,
        "ingredients" : ingredients,
        "instructions": instructions,
    }


# Clean + deduplicate (by title)
seen_titles = set()
cleaned = []
for r in raw:
    c = clean_recipe(r)
    if c is None:
        continue
    if c["title"].lower() in seen_titles:
        continue
    seen_titles.add(c["title"].lower())
    cleaned.append(c)

with open("recipes_clean.json", "w", encoding="utf-8") as f:
    json.dump(cleaned, f, indent=2, ensure_ascii=False)

print(f"Clean count: {len(cleaned)} → recipes_clean.json")
# Out:
# Raw count : 41
# Clean count: 41 → recipes_clean.json

# %%
# Chunking Strategy
# Strategy: recipe-level chunking.
# • Ingredients + Instructions stay together in one chunk.
# • Long recipes (>800 chars) are split with 50-char overlap.
# • Every chunk carries full metadata.

MAX_CHUNK_CHARS = 800
OVERLAP_CHARS   = 50


def recipe_to_text(r: dict) -> str:
    """Convert a recipe dict into a single readable string."""
    parts = []
    parts.append(f"Recipe: {r['title']}")
    if r.get("description"):
        parts.append(f"Description: {r['description']}")
    parts.append("Ingredients:")
    for ing in r["ingredients"]:
        parts.append(f"  - {ing}")
    parts.append("Instructions:")
    for i, step in enumerate(r["instructions"], 1):
        parts.append(f"  Step {i}: {step}")
    return "\n".join(parts)


def split_long_text(text: str, max_chars: int, overlap: int) -> list[str]:
    """Split text into overlapping chunks if it exceeds max_chars."""
    if len(text) <= max_chars:
        return [text]

    chunks = []
    start = 0
    while start < len(text):
        end = start + max_chars
        chunk = text[start:end]
        chunks.append(chunk)
        if end >= len(text):
            break
        start = end - overlap   # overlap with next chunk
    return chunks


with open("recipes_clean.json", "r", encoding="utf-8") as f:
    cleaned = json.load(f)

chunks = []
chunk_id = 0

for recipe in cleaned:
    full_text = recipe_to_text(recipe)
    parts = split_long_text(full_text, MAX_CHUNK_CHARS, OVERLAP_CHARS)

    for part_idx, text_part in enumerate(parts):
        chunks.append({
            "text": text_part,
            "metadata": {
                "chunk_id" : f"chunk_{chunk_id}",
                "title"    : recipe["title"],
                "url"      : recipe["source_url"],
                "category" : recipe["category"],
                "part"     : part_idx,
                "record_id": recipe["record_id"],
            }
        })
        chunk_id += 1

with open("chunks.json", "w", encoding="utf-8") as f:
    json.dump(chunks, f, indent=2, ensure_ascii=False)

print(f"{len(chunks)} chunks → chunks.json")
print("\nSample chunk:")
print(json.dumps(chunks[0], indent=2))
# Out:
# 65 chunks → chunks.json
#
# Sample chunk:
# {
#   "text": "Recipe: Oatmeal Breakfast Cookies\nIngredients:\n  - 3 \u00bc cups old-fashioned oats, divided\n  - \u00bd cup chopped walnuts\n  - \u2153 cup raisins\n  - 2 tablespoons ground flax seeds\n  - 1 teaspoon ground cinnamon\n  - \u00bc teaspoon baking powder\n  - \u00bc teaspoon salt\n  - 2 ripe bananas\n  - 2 large eggs\n  - \u2153 cup unsweetened applesauce\n  - 1 tablespoon honey\n  - 1 tablespoon vanilla extract\nInstructions:\n  Step 1: Preheat the oven to 350 degrees F (175 degrees C). Line 2 baking sheets with parchment paper.\n  Step 2: Grind 2 1/4 cups oats in a food processor to yield 2 cups ground oats. Add walnuts, raisins, flax seeds, cinnamon, baking powder, and salt. Stir in remaining 1 cup oats. Stir thoroughly with a spoon, but do not grind further.\n  Step 3: Make a well in the center of oat mixture. Add bananas, eggs, ap",
#   "metadata": {
#     "chunk_id": "chunk_0",
#     "title": "Oatmeal Breakfast Cookies",
#     "url": "https://www.allrecipes.com/recipe/268399/oatmeal-breakfast-cookies/",
#     "category": "Breakfast",
#     "part": 0,
#     "record_id": 1
#   }
# }

# %%
# Embedding
# Model : all-MiniLM-L6-v2  (sentence-transformers)
# Why   : Fast, lightweight, free, works offline. Good at
#         semantic similarity for short English paragraphs,
#         which matches our recipe chunks perfectly.

with open("chunks.json", "r", encoding="utf-8") as f:
    chunks = json.load(f)

texts = [c["text"] for c in chunks]

print(" Loading embedding model...")
embed_model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

print(f" Embedding {len(texts)} chunks...")
embeddings = embed_model.encode(texts, show_progress_bar=True, convert_to_numpy=True)

# embeddings shape
print(f" Embedding shape: {embeddings.shape}")

# Save embeddings for reuse (avoids re-running if kernel restarts)
np.save("embeddings.npy", embeddings)
print(" Saved → embeddings.npy")
# Out:
#  Loading embedding model...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
#  Embedding 65 chunks...
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
#  Embedding shape: (65, 384)
#  Saved → embeddings.npy

# %%
#  FAISS Indexing

embeddings = np.load("embeddings.npy")
DIM = embeddings.shape[1]          

# FlatL2 = exact nearest-neighbour search using L2 (Euclidean) distance
index = faiss.IndexFlatL2(DIM)
index.add(embeddings.astype(np.float32))

print(f"FAISS index built — {index.ntotal} vectors (dim={DIM})")

# Save index to disk
faiss.write_index(index, "recipe_index.faiss")
print("Saved → recipe_index.faiss")

# Load it back (proves save/load works)
index = faiss.read_index("recipe_index.faiss")
print(f"Loaded index — {index.ntotal} vectors")
# Out:
# FAISS index built — 65 vectors (dim=384)
# Saved → recipe_index.faiss
# Loaded index — 65 vectors

# %%
# Retrieval Function

with open("chunks.json", "r", encoding="utf-8") as f:
    chunks = json.load(f)

index = faiss.read_index("recipe_index.faiss")
embed_model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")


def retrieve(query: str, top_k: int = 5) -> list[dict]:
    """
    Given a user query, return the top_k most similar recipe chunks.

    Returns a list of dicts, each with:
      - text           : the chunk text
      - metadata       : title, url, category, chunk_id …
      - similarity_score : L2 distance (lower = more similar)
    """
    # 1. Embed the query with the same model used for indexing
    query_vec = embed_model.encode([query], convert_to_numpy=True).astype(np.float32)

    # 2. Search FAISS
    distances, indices = index.search(query_vec, top_k)

    # 3. Build results
    results = []
    for dist, idx in zip(distances[0], indices[0]):
        if idx == -1:          # FAISS returns -1 when fewer results exist
            continue
        chunk = chunks[idx]
        results.append({
            "text"            : chunk["text"],
            "metadata"        : chunk["metadata"],
            "similarity_score": float(dist),
        })
    return results


# Quick test
test_results = retrieve("easy chocolate cake recipe")
for r in test_results:
    print(f"[Score: {r['similarity_score']:.3f}] {r['metadata']['title']} — {r['metadata']['url']}")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# [Score: 0.979] Orange Party Cake — https://www.allrecipes.com/recipe/15678/orange-party-cake-i/
# [Score: 1.114] Oatmeal Breakfast Cookies — https://www.allrecipes.com/recipe/268399/oatmeal-breakfast-cookies/
# [Score: 1.167] Oatmeal Breakfast Cookies — https://www.allrecipes.com/recipe/268399/oatmeal-breakfast-cookies/
# [Score: 1.211] Easy Sausage Gravy and Biscuits — https://www.allrecipes.com/recipe/216391/easy-sausage-gravy-and-biscuits/
# [Score: 1.212] Apple Fritter Pancakes — https://www.allrecipes.com/recipe/8496144/apple-fritter-pancakes/

# %%
! pip install -U google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in c:\users\nt\anaconda3\lib\site-packages (0.8.6)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\users\nt\anaconda3\lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\users\nt\anaconda3\lib\site-packages (from google-generativeai) (2.31.0)
# Requirement already satisfied: google-api-python-client in c:\users\nt\anaconda3\lib\site-packages (from google-generativeai) (2.198.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\nt\anaconda3\lib\site-packages (from google-generativeai) (2.55.1)
# Requirement already satisfied: protobuf in c:\users\nt\anaconda3\lib\site-packages (from google-generativeai) (5.29.6)
# Requirement already satisfied: pydantic in c:\users\nt\anaconda3\lib\site-packages (from google-generativeai) (2.13.4)
# Requirement already satisfied: tqdm in c:\users\nt\anaconda3\lib\site-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in c:\users\nt\anaconda3\lib\site-packages (from google-generativeai) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\nt\anaconda3\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.28.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in c:\users\nt\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (1.75.0)
# Requirement already satisfied: requests<3.0.0,>=2.33.0 in c:\users\nt\anaconda3\lib\site-packages (from google-api-core->google-generativeai) (2.34.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.41.0 in c:\users\nt\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.80.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.41.0 in c:\users\nt\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\nt\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\nt\anaconda3\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (46.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\nt\anaconda3\lib\site-packages (from requests<3.0.0,>=2.33.0->google-api-core->google-generativeai) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nt\anaconda3\lib\site-packages (from requests<3.0.0,>=2.33.0->google-api-core->google-generativeai) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\nt\anaconda3\lib\site-packages (from requests<3.0.0,>=2.33.0->google-api-core->google-generativeai) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\nt\anaconda3\lib\site-packages (from requests<3.0.0,>=2.33.0->google-api-core->google-generativeai) (2025.11.12)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\nt\anaconda3\lib\site-packages (from cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\nt\anaconda3\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\nt\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\nt\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.32.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\nt\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (0.4.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\nt\anaconda3\lib\site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: pyparsing<4,>=3.1 in c:\users\nt\anaconda3\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.5)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\nt\anaconda3\lib\site-packages (from pydantic->google-generativeai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\nt\anaconda3\lib\site-packages (from pydantic->google-generativeai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\nt\anaconda3\lib\site-packages (from pydantic->google-generativeai) (0.4.2)
# Requirement already satisfied: colorama in c:\users\nt\anaconda3\lib\site-packages (from tqdm->google-generativeai) (0.4.6)

# %%
! pip install -q google-genai

# %%
from dotenv import load_dotenv
import os
load_dotenv(dotenv_path=r"C:\Users\NT\ai-final-project\.ipynb_checkpoints\.env")
key = os.getenv("GEMINI_API_KEY")
print(key)
# Out:
# AQ.Ab8RN6KmQeYiFFfeo0N3lVfyAxnh4mPaUraHNeFcc_DIwq9c0Q

# %%
# Gemini Answer Generation
from dotenv import load_dotenv
import os

load_dotenv(dotenv_path=r"C:\Users\NT\ai-final-project\.vscode\.env")
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")
print("Key found:", GEMINI_API_KEY is not None)
genai.configure(api_key=GEMINI_API_KEY)

# Use the new flash model
try:
    gemini = genai.GenerativeModel("gemini-2.0-flash-lite")
    print("Using: gemini-2.0-flash-lite")
except Exception as e:
    try:
        gemini = genai.GenerativeModel("gemini-1.5-flash")
        print("Using: gemini-1.5-flash")
    except Exception as e:
        try:
            gemini = genai.GenerativeModel("gemini-pro")
            print("Using: gemini-pro")
        except Exception as e:
            print(f"ERROR: {e}")
            print("Get a new API key from: https://aistudio.google.com/app/apikey")
            exit()

print("Gemini connected")

def build_prompt(query: str, retrieved_chunks: list[dict]):
    context_block = ""
    for i, chunk in enumerate(retrieved_chunks, 1):
        meta = chunk["metadata"]
        context_block += (
            f"--- Source {i} ---\n"
            f"Title: {meta.get('title','')}\n"
            f"Category: {meta.get('category','')}\n"
            f"URL: {meta.get('url','')}\n"
            f"{chunk['text']}\n\n"
        )
    
    prompt = f"""
You are a recipe assistant.

Answer ONLY using the recipe context.

Rules:
- Do not use outside knowledge.
- Do not invent information.
- If missing information say:
"I don't have enough information in the provided recipes."

Context:

{context_block}

Question:

{query}

Answer:
"""
    return prompt

def answer_question(query: str, top_k=5):
    retrieved = retrieve(query, top_k=top_k)
    if not retrieved:
        return "No relevant recipes found."
    prompt = build_prompt(query, retrieved)
    try:
        response = gemini.generate_content(prompt)
        return response.text
    except Exception as e:
        return f"Error: {e}"

print("Gemini RAG function ready")
# Out:
# Key found: True
# Using: gemini-2.0-flash-lite
# Gemini connected
# Gemini RAG function ready

# %%
# Test Questions
test_questions = [
    "How do I make pancakes for breakfast?",
    "What is a simple chicken soup recipe?",
    "How do I bake a chocolate cake?",
    "Give me an easy salad recipe with tomatoes.",
    "What dessert can I make with eggs and sugar?",
]

for q in test_questions:
    print(f"\n{'='*60}")
    print(f"Question: {q}")
    print(f"{'='*60}")
    
    # Show retrieved chunks
    retrieved = retrieve(q, top_k=5)
    print("\n--- Retrieved Chunks ---")
    for i, r in enumerate(retrieved, 1):
        print(f"\nChunk {i}:")
        print(f"  Title   : {r['metadata']['title']}")
        print(f"  Category: {r['metadata']['category']}")
        print(f"  URL     : {r['metadata']['url']}")
        print(f"  Score   : {r['similarity_score']:.4f}")
        print(f"  Text    : {r['text'][:200]}...")
    
    # Show answer
    print("\n--- Answer ---")
    answer = answer_question(q)
    print(answer)
# Out:
# ============================================================
# Question: How do I make pancakes for breakfast?
# ============================================================
#
# --- Retrieved Chunks ---
#
# Chunk 1:
#   Title   : Apple Fritter Pancakes
#   Category: Breakfast
#   URL     : https://www.allrecipes.com/recipe/8496144/apple-fritter-pancakes/
#   Score   : 0.7825
#   Text    : , and baking soda. Mix until flour disappears and batter is thick yet spoonable. ALLRECIPES/VICTORIA JEMPTY
#   Step 3: Melt butter in a skillet over medium heat. Add tablespoonfuls of apple batter to t...
#
# Chunk 2:
#   Title   : Apple Fritter Pancakes
#   Category: Breakfast
#   URL     : https://www.allrecipes.com/recipe/8496144/apple-fritter-pancakes/
#   Score   : 0.8617
#   Text    : Recipe: Apple Fritter Pancakes
# Ingredients:
#   - 1 large egg
#   - 1 tablespoon white sugar
#   - ⅛ teaspoon ground cinnamon, or to taste
#   - 1 pinch ground ginger
#   - 1 pinch nutmeg
#   - ¼ teaspoon kosher ...
#
# Chunk 3:
#   Title   : Pumpkin Waffles
#   Category: Breakfast
#   URL     : https://www.allrecipes.com/recipe/65691/pumpkin-waffles-with-apple-cider-syrup/
#   Score   : 0.8755
#   Text    : owl. Whip egg whites in a clean dry bowl until soft peaks form. Dotdash Meredith Food Studios
#   Step 3: Stir flour mixture and 1/4 cup melted butter into pumpkin mixture just until combined. Fold 1/3 ...
#
# Chunk 4:
#   Title   : Easy Sausage Gravy and Biscuits
#   Category: Breakfast
#   URL     : https://www.allrecipes.com/recipe/216391/easy-sausage-gravy-and-biscuits/
#   Score   : 0.9171
#   Text    : Step 4: Stir in flour until well combined. Dotdash Meredith Food Studios
#   Step 5: Gradually add milk, stirring continuously, until the gravy thickens and comes to a boil. Reduce heat to medium-low; s...
#
# Chunk 5:
#   Title   : Pumpkin Waffles
#   Category: Breakfast
#   URL     : https://www.allrecipes.com/recipe/65691/pumpkin-waffles-with-apple-cider-syrup/
#   Score   : 0.9252
#   Text    : Recipe: Pumpkin Waffles
# Ingredients:
#   - 2 ½ cups all-purpose flour
#   - ¼ cup packed brown sugar
#   - 4 teaspoons baking powder
#   - 2 teaspoons ground cinnamon
#   - 1 teaspoon ground allspice
#   - 1 teas...
#
# --- Answer ---
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash-lite
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash-lite
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-2.0-flash-lite
# Please retry in 20.668899364s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# , retry_delay {
#   seconds: 20
# }
# ]
#
# ============================================================
# Question: What is a simple chicken soup recipe?
# ============================================================
#
# --- Retrieved Chunks ---
#
# Chunk 1:
#   Title   : Thai Red Curry Soup
#   Category: Dinner
#   URL     : https://www.allrecipes.com/recipe/274422/thai-red-curry-soup/
#   Score   : 0.7979
#   Text    : blender, covering opening with a dish towel, and blend until pureed. Return soup to pot.
#   Step 6: Stir in green onions, cilantro, basil, and lime juice. Divide soup evenly among 6 bowls and top each ...
#
# Chunk 2:
#   Title   : Thai Red Curry Soup
#   Category: Dinner
#   URL     : https://www.allrecipes.com/recipe/274422/thai-red-curry-soup/
#   Score   : 0.8947
#   Text    : Recipe: Thai Red Curry Soup
# Ingredients:
#   - 2 tablespoons olive oil, divided
#   - 18 large shrimp, peeled and deveined
#   - ¼ teaspoon kosher salt
#   - ¼ teaspoon ground black pepper
#   - 1 large red bel...
#
# Chunk 3:
#   Title   : Easy Egg Salad
#   Category: Salads
#   URL     : https://www.allrecipes.com/recipe/222514/easy-egg-salad/
#   Score   : 0.9679
#   Text    : Recipe: Easy Egg Salad
# Ingredients:
#   - 8 hard-cooked eggs, chopped
#   - ¼ cup plain fat-free yogurt
#   - 1 tablespoon parsley flakes
#   - ¼ teaspoon onion powder
#   - ¼ teaspoon paprika
#   - ¼ teaspoon sa...
#
# Chunk 4:
#   Title   : Thai Red Curry Soup
#   Category: Dinner
#   URL     : https://www.allrecipes.com/recipe/274422/thai-red-curry-soup/
#   Score   : 0.9907
#   Text    : over medium heat. Season shrimp with salt and pepper. Add shrimp to pot and cook 2 to 3 minutes or until pink, turning halfway through. Set aside.
#   Step 2: Add remaining olive oil, bell pepper, onion...
#
# Chunk 5:
#   Title   : Barley, Shrimp, and Corn Salad
#   Category: Salads
#   URL     : https://www.allrecipes.com/recipe/34620/barley-shrimp-and-corn-salad/
#   Score   : 1.0647
#   Text    : Recipe: Barley, Shrimp, and Corn Salad
# Ingredients:
#   - 1 cup barley
#   - 2 ½ cups water
#   - 1 pound cooked bay shrimp
#   - 2 cups frozen corn, thawed
#   - ½ cup diced green bell pepper
#   - ½ cup diced r...
#
# --- Answer ---
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash-lite
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash-lite
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-2.0-flash-lite
# Please retry in 20.254134305s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# , retry_delay {
#   seconds: 20
# }
# ]
#
# ============================================================
# Question: How do I bake a chocolate cake?
# ============================================================
#
# --- Retrieved Chunks ---
#
# Chunk 1:
#   Title   : Orange Party Cake
#   Category: Desserts
#   URL     : https://www.allrecipes.com/recipe/15678/orange-party-cake-i/
#   Score   : 0.9989
#   Text    : Recipe: Orange Party Cake
# Ingredients:
#   - 1 (15.25 ounce) package white cake mix
#   - 1 (6 ounce) package orange flavored Jell-O® mix
#   - 4 large eggs
#   - ¾ cup vegetable oil
#   - ¾ cup water
#   - 4 tea...
#
# Chunk 2:
#   Title   : Oatmeal Breakfast Cookies
#   Category: Breakfast
#   URL     : https://www.allrecipes.com/recipe/268399/oatmeal-breakfast-cookies/
#   Score   : 1.0426
#   Text    : n the center of oat mixture. Add bananas, eggs, applesauce, honey, and vanilla extract. Mash bananas and stir until dough is well combined.
#   Step 4: Drop tablespoonfuls of dough onto the prepared bak...
#
# Chunk 3:
#   Title   : Apple Fritter Pancakes
#   Category: Breakfast
#   URL     : https://www.allrecipes.com/recipe/8496144/apple-fritter-pancakes/
#   Score   : 1.1381
#   Text    : , and baking soda. Mix until flour disappears and batter is thick yet spoonable. ALLRECIPES/VICTORIA JEMPTY
#   Step 3: Melt butter in a skillet over medium heat. Add tablespoonfuls of apple batter to t...
#
# Chunk 4:
#   Title   : Apple Fritter Pancakes
#   Category: Breakfast
#   URL     : https://www.allrecipes.com/recipe/8496144/apple-fritter-pancakes/
#   Score   : 1.2693
#   Text    : Recipe: Apple Fritter Pancakes
# Ingredients:
#   - 1 large egg
#   - 1 tablespoon white sugar
#   - ⅛ teaspoon ground cinnamon, or to taste
#   - 1 pinch ground ginger
#   - 1 pinch nutmeg
#   - ¼ teaspoon kosher ...
#
# Chunk 5:
#   Title   : Pumpkin Waffles
#   Category: Breakfast
#   URL     : https://www.allrecipes.com/recipe/65691/pumpkin-waffles-with-apple-cider-syrup/
#   Score   : 1.2810
#   Text    : owl. Whip egg whites in a clean dry bowl until soft peaks form. Dotdash Meredith Food Studios
#   Step 3: Stir flour mixture and 1/4 cup melted butter into pumpkin mixture just until combined. Fold 1/3 ...
#
# --- Answer ---
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-2.0-flash-lite
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash-lite
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash-lite
# Please retry in 19.874796408s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# , retry_delay {
#   seconds: 19
# }
# ]
#
# ============================================================
# Question: Give me an easy salad recipe with tomatoes.
# ============================================================
#
# --- Retrieved Chunks ---
#
# Chunk 1:
#   Title   : Garden Pasta Salad
#   Category: Salads
#   URL     : https://www.allrecipes.com/recipe/11883/garden-pasta-salad/
#   Score   : 0.7041
#   Text    : Recipe: Garden Pasta Salad
# Ingredients:
#   - 1 (16 ounce) package tri-color rotini pasta
#   - 2 large tomatoes, diced
#   - 2 stalks celery, chopped
#   - ½ cup thinly sliced carrots
#   - ½ cup chopped green...
#
# Chunk 2:
#   Title   : Winter Fruit Salad with Poppyseed Dressing
#   Category: Salads
#   URL     : https://www.allrecipes.com/recipe/13482/winter-fruit-salad-with-lemon-poppyseed-dressing/
#   Score   : 0.8130
#   Text    : Recipe: Winter Fruit Salad with Poppyseed Dressing
# Ingredients:
#   - ½ cup white sugar
#   - ½ cup lemon juice
#   - 2 teaspoons diced onion
#   - 1 teaspoon Dijon-style prepared mustard
#   - ½ teaspoon salt
# ...
#
# Chunk 3:
#   Title   : Barley, Shrimp, and Corn Salad
#   Category: Salads
#   URL     : https://www.allrecipes.com/recipe/34620/barley-shrimp-and-corn-salad/
#   Score   : 0.8157
#   Text    :  Season with salt and pepper. Pour dressing over barley salad, and toss to combine....
#
# Chunk 4:
#   Title   : Winter Fruit Salad with Poppyseed Dressing
#   Category: Salads
#   URL     : https://www.allrecipes.com/recipe/13482/winter-fruit-salad-with-lemon-poppyseed-dressing/
#   Score   : 0.8318
#   Text    :  to mix.
#   Step 2: Toss romaine lettuce, shredded Swiss cheese, cashews, dried cranberries, apple, and pear together in a large serving bowl. Pour dressing over salad just before serving, and toss to ...
#
# Chunk 5:
#   Title   : Easy Egg Salad
#   Category: Salads
#   URL     : https://www.allrecipes.com/recipe/222514/easy-egg-salad/
#   Score   : 0.8561
#   Text    : Recipe: Easy Egg Salad
# Ingredients:
#   - 8 hard-cooked eggs, chopped
#   - ¼ cup plain fat-free yogurt
#   - 1 tablespoon parsley flakes
#   - ¼ teaspoon onion powder
#   - ¼ teaspoon paprika
#   - ¼ teaspoon sa...
#
# --- Answer ---
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-2.0-flash-lite
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash-lite
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash-lite
# Please retry in 19.618475249s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# , retry_delay {
#   seconds: 19
# }
# ]
#
# ============================================================
# Question: What dessert can I make with eggs and sugar?
# ============================================================
#
# --- Retrieved Chunks ---
#
# Chunk 1:
#   Title   : Apple Fritter Pancakes
#   Category: Breakfast
#   URL     : https://www.allrecipes.com/recipe/8496144/apple-fritter-pancakes/
#   Score   : 0.9562
#   Text    : Recipe: Apple Fritter Pancakes
# Ingredients:
#   - 1 large egg
#   - 1 tablespoon white sugar
#   - ⅛ teaspoon ground cinnamon, or to taste
#   - 1 pinch ground ginger
#   - 1 pinch nutmeg
#   - ¼ teaspoon kosher ...
#
# Chunk 2:
#   Title   : Pumpkin Waffles
#   Category: Breakfast
#   URL     : https://www.allrecipes.com/recipe/65691/pumpkin-waffles-with-apple-cider-syrup/
#   Score   : 0.9625
#   Text    : owl. Whip egg whites in a clean dry bowl until soft peaks form. Dotdash Meredith Food Studios
#   Step 3: Stir flour mixture and 1/4 cup melted butter into pumpkin mixture just until combined. Fold 1/3 ...
#
# Chunk 3:
#   Title   : Pumpkin Waffles
#   Category: Breakfast
#   URL     : https://www.allrecipes.com/recipe/65691/pumpkin-waffles-with-apple-cider-syrup/
#   Score   : 0.9860
#   Text    : Recipe: Pumpkin Waffles
# Ingredients:
#   - 2 ½ cups all-purpose flour
#   - ¼ cup packed brown sugar
#   - 4 teaspoons baking powder
#   - 2 teaspoons ground cinnamon
#   - 1 teaspoon ground allspice
#   - 1 teas...
#
# Chunk 4:
#   Title   : Orange Party Cake
#   Category: Desserts
#   URL     : https://www.allrecipes.com/recipe/15678/orange-party-cake-i/
#   Score   : 0.9915
#   Text    : Recipe: Orange Party Cake
# Ingredients:
#   - 1 (15.25 ounce) package white cake mix
#   - 1 (6 ounce) package orange flavored Jell-O® mix
#   - 4 large eggs
#   - ¾ cup vegetable oil
#   - ¾ cup water
#   - 4 tea...
#
# Chunk 5:
#   Title   : Apple Fritter Pancakes
#   Category: Breakfast
#   URL     : https://www.allrecipes.com/recipe/8496144/apple-fritter-pancakes/
#   Score   : 1.0037
#   Text    : , and baking soda. Mix until flour disappears and batter is thick yet spoonable. ALLRECIPES/VICTORIA JEMPTY
#   Step 3: Melt butter in a skillet over medium heat. Add tablespoonfuls of apple batter to t...
#
# --- Answer ---
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash-lite
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash-lite
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-2.0-flash-lite
# Please retry in 19.021743065s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# , retry_delay {
#   seconds: 19
# }
# ]

# %%
answer = answer_question("How do I make pancakes?")
print(answer)
# Out:
# Error: 429 You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash-lite
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash-lite
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-2.0-flash-lite
# Please retry in 13.408516447s. [links {
#   description: "Learn more about Gemini API quotas"
#   url: "https://ai.google.dev/gemini-api/docs/rate-limits"
# }
# , violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerDayPerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_requests"
#   quota_id: "GenerateRequestsPerMinutePerProjectPerModel-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# violations {
#   quota_metric: "generativelanguage.googleapis.com/generate_content_free_tier_input_token_count"
#   quota_id: "GenerateContentInputTokensPerModelPerMinute-FreeTier"
#   quota_dimensions {
#     key: "model"
#     value: "gemini-2.0-flash-lite"
#   }
#   quota_dimensions {
#     key: "location"
#     value: "global"
#   }
# }
# , retry_delay {
#   seconds: 13
# }
# ]
